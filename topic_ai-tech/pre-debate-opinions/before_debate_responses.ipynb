# %%
import pandas as pd
# Out:
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.
# Intel MKL WARNING: Support of Intel(R) Streaming SIMD Extensions 4.2 (Intel(R) SSE4.2) enabled only processors has been deprecated. Intel oneAPI Math Kernel Library 2025.0 will require Intel(R) Advanced Vector Extensions (Intel(R) AVX) instructions.

# %%
# Initialize an empty dictionary to hold data for the DataFrame
import os 
data = {}
data_dir = './before'

# Load each CSV file and add its data to the dictionary
for filename in os.listdir(data_dir):
    if filename.endswith('.csv'):
        # Load the file into a DataFrame
        path = os.path.join(data_dir, filename)
        df = pd.read_csv(path)
        
        # Set the question index as the index for easy merging
        df.set_index('Query', inplace=True)
        
        # Add the answers to the data dictionary with filename as the key
        data[filename.split(".csv")[0]] = df['Results']

# Combine all data into a single DataFrame
combined_df = pd.DataFrame(data)

# Display the first few rows of the DataFrame
print(combined_df.head())
# Out:
#                                                      young_female_writer  \
# Query
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# How worried are you, if at all, about the devel...       Not too worried
#
#                                                        young_male_researcher  \
# Query
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...  Will probably not happen
# How worried are you, if at all, about the devel...          Somewhat worried
#
#                                                    elder_male_travel blogger  \
# Query
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# How worried are you, if at all, about the devel...          Somewhat worried
#
#                                                        young_male_writer  \
# Query
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# How worried are you, if at all, about the devel...       Not too worried
#
#                                                    young_male_travel blogger  \
# Query
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# How worried are you, if at all, about the devel...           Not too worried
#
#                                                    young_female_researcher  \
# Query
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# How worried are you, if at all, about the devel...        Somewhat worried
#
#                                                    elder_male_sports analyst  \
# Query
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...     Will probably happen.
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# How worried are you, if at all, about the devel...          Somewhat worried
#
#                                                    young_male_sports analyst  \
# Query
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...  Will probably not happen
# How worried are you, if at all, about the devel...           Not too worried
#
#                                                    elder_female_data scientist  \
# Query
# Do you think the following will or will not hap...        Will probably happen
# Do you think the following will or will not hap...        Will probably happen
# Do you think the following will or will not hap...        Will probably happen
# Do you think the following will or will not hap...    Will probably not happen
# How worried are you, if at all, about the devel...            Somewhat worried
#
#                                                    young_female_journalist  \
# Query
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# How worried are you, if at all, about the devel...        Somewhat worried
#
#                                                     ...  \
# Query                                               ...
# Do you think the following will or will not hap...  ...
# Do you think the following will or will not hap...  ...
# Do you think the following will or will not hap...  ...
# Do you think the following will or will not hap...  ...
# How worried are you, if at all, about the devel...  ...
#
#                                                    young_male_genealogist  \
# Query
# Do you think the following will or will not hap...   Will probably happen
# Do you think the following will or will not hap...   Will probably happen
# Do you think the following will or will not hap...   Will probably happen
# Do you think the following will or will not hap...   Will probably happen
# How worried are you, if at all, about the devel...        Not too worried
#
#                                                    elder_female_historian  \
# Query
# Do you think the following will or will not hap...   Will probably happen
# Do you think the following will or will not hap...   Will probably happen
# Do you think the following will or will not hap...   Will probably happen
# Do you think the following will or will not hap...   Will probably happen
# How worried are you, if at all, about the devel...       Somewhat worried
#
#                                                    elder_male_data scientist  \
# Query
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# How worried are you, if at all, about the devel...          Somewhat worried
#
#                                                    young_male_data scientist  \
# Query
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# Do you think the following will or will not hap...      Will probably happen
# How worried are you, if at all, about the devel...          Somewhat worried
#
#                                                    elder_male_sports journalist  \
# Query
# Do you think the following will or will not hap...         Will probably happen
# Do you think the following will or will not hap...         Will probably happen
# Do you think the following will or will not hap...         Will probably happen
# Do you think the following will or will not hap...         Will probably happen
# How worried are you, if at all, about the devel...             Somewhat worried
#
#                                                      elder_female_writer  \
# Query
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# How worried are you, if at all, about the devel...      Somewhat worried
#
#                                                    elder_female_journalist  \
# Query
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# How worried are you, if at all, about the devel...        Somewhat worried
#
#                                                    elder_male_journalist  \
# Query
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# Do you think the following will or will not hap...  Will probably happen
# How worried are you, if at all, about the devel...      Somewhat worried
#
#                                                    young_female_genealogist  \
# Query
# Do you think the following will or will not hap...     Will probably happen
# Do you think the following will or will not hap...     Will probably happen
# Do you think the following will or will not hap...     Will probably happen
# Do you think the following will or will not hap...     Will probably happen
# How worried are you, if at all, about the devel...          Not too worried
#
#                                                    elder_male_data analyst
# Query
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# Do you think the following will or will not hap...    Will probably happen
# How worried are you, if at all, about the devel...        Somewhat worried
#
# [5 rows x 40 columns]

# %%
combined_df = combined_df.reset_index()

# %%
value_counts_per_question = combined_df.drop(columns=["Query"]).apply(lambda row: row.value_counts(), axis=1)

# Display the result
print(value_counts_per_question)
# Out:
#     Acceptable  Better off  Completely agree  Completely agree.  Favor  \
# 0          NaN         NaN               NaN                NaN    NaN
# 1          NaN         NaN               NaN                NaN    NaN
# 2          NaN         NaN               NaN                NaN    NaN
# 3          NaN         NaN               NaN                NaN    NaN
# 4          NaN         NaN               NaN                NaN    NaN
# 5          NaN         NaN               NaN                NaN    NaN
# 6          NaN         NaN               NaN                NaN   40.0
# 7          NaN         NaN               NaN                NaN   36.0
# 8          NaN         NaN               NaN                NaN   27.0
# 9          NaN         NaN               NaN                NaN    NaN
# 10         NaN         NaN               NaN                NaN    NaN
# 11        27.0         NaN               NaN                NaN    NaN
# 12         6.0         NaN               NaN                NaN    NaN
# 13         NaN         NaN               NaN                NaN    NaN
# 14         NaN         NaN               NaN                NaN    NaN
# 15         NaN         NaN               NaN                NaN    NaN
# 16         NaN         NaN               NaN                NaN    NaN
# 17         NaN         NaN               NaN                NaN    NaN
# 18         NaN        40.0               NaN                NaN    NaN
# 19         NaN         NaN              37.0                3.0    NaN
#
#     Mostly positive  Mostly positive.   No  Not sure  Not too enthusiastic  \
# 0               NaN               NaN  NaN       NaN                   NaN
# 1               NaN               NaN  NaN       NaN                   NaN
# 2               NaN               NaN  NaN       NaN                   NaN
# 3               NaN               NaN  NaN       NaN                   NaN
# 4               NaN               NaN  NaN       NaN                   NaN
# 5               NaN               NaN  NaN       NaN                   NaN
# 6               NaN               NaN  NaN       NaN                   NaN
# 7               NaN               NaN  NaN       NaN                   NaN
# 8               NaN               NaN  NaN       NaN                   NaN
# 9               NaN               NaN  NaN       NaN                   NaN
# 10              NaN               NaN  NaN       NaN                  12.0
# 11              NaN               NaN  NaN      13.0                   NaN
# 12              NaN               NaN  NaN      27.0                   NaN
# 13              NaN               NaN  NaN       5.0                   NaN
# 14              NaN               NaN  NaN       NaN                   NaN
# 15              NaN               NaN  NaN       NaN                   NaN
# 16             39.0               1.0  NaN       NaN                   NaN
# 17              NaN               NaN  5.0       NaN                   NaN
# 18              NaN               NaN  NaN       NaN                   NaN
# 19              NaN               NaN  NaN       NaN                   NaN
#
#     ...  Scientists should take an active role in public  \
# 0   ...                                              NaN
# 1   ...                                              NaN
# 2   ...                                              NaN
# 3   ...                                              NaN
# 4   ...                                              NaN
# 5   ...                                              NaN
# 6   ...                                              NaN
# 7   ...                                              NaN
# 8   ...                                              NaN
# 9   ...                                              NaN
# 10  ...                                              NaN
# 11  ...                                              NaN
# 12  ...                                              NaN
# 13  ...                                              NaN
# 14  ...                                              NaN
# 15  ...                                             40.0
# 16  ...                                              NaN
# 17  ...                                              NaN
# 18  ...                                              NaN
# 19  ...                                              NaN
#
#     Somewhat enthusiastic  Somewhat safe  Somewhat worried  Strongly favor  \
# 0                     NaN            NaN               NaN             NaN
# 1                     NaN            NaN               NaN             NaN
# 2                     NaN            NaN               NaN             NaN
# 3                     NaN            NaN               NaN             NaN
# 4                     NaN            NaN              25.0             NaN
# 5                     NaN           40.0               NaN             NaN
# 6                     NaN            NaN               NaN             NaN
# 7                     NaN            NaN               NaN             4.0
# 8                     NaN            NaN               NaN            13.0
# 9                     NaN            NaN              40.0             NaN
# 10                   28.0            NaN               NaN             NaN
# 11                    NaN            NaN               NaN             NaN
# 12                    NaN            NaN               NaN             NaN
# 13                    NaN            NaN               NaN             NaN
# 14                    NaN            NaN               NaN             NaN
# 15                    NaN            NaN               NaN             NaN
# 16                    NaN            NaN               NaN             NaN
# 17                    NaN            NaN               NaN             NaN
# 18                    NaN            NaN               NaN             NaN
# 19                    NaN            NaN               NaN             NaN
#
#     Unacceptable  Will probably happen  Will probably happen.  \
# 0            NaN                  40.0                    NaN
# 1            NaN                  37.0                    2.0
# 2            NaN                  40.0                    NaN
# 3            NaN                  32.0                    1.0
# 4            NaN                   NaN                    NaN
# 5            NaN                   NaN                    NaN
# 6            NaN                   NaN                    NaN
# 7            NaN                   NaN                    NaN
# 8            NaN                   NaN                    NaN
# 9            NaN                   NaN                    NaN
# 10           NaN                   NaN                    NaN
# 11           NaN                   NaN                    NaN
# 12           7.0                   NaN                    NaN
# 13          35.0                   NaN                    NaN
# 14          40.0                   NaN                    NaN
# 15           NaN                   NaN                    NaN
# 16           NaN                   NaN                    NaN
# 17           NaN                   NaN                    NaN
# 18           NaN                   NaN                    NaN
# 19           NaN                   NaN                    NaN
#
#     Will probably not happen   Yes
# 0                        NaN   NaN
# 1                        1.0   NaN
# 2                        NaN   NaN
# 3                        7.0   NaN
# 4                        NaN   NaN
# 5                        NaN   NaN
# 6                        NaN   NaN
# 7                        NaN   NaN
# 8                        NaN   NaN
# 9                        NaN   NaN
# 10                       NaN   NaN
# 11                       NaN   NaN
# 12                       NaN   NaN
# 13                       NaN   NaN
# 14                       NaN   NaN
# 15                       NaN   NaN
# 16                       NaN   NaN
# 17                       NaN  35.0
# 18                       NaN   NaN
# 19                       NaN   NaN
#
# [20 rows x 21 columns]

# %%
value_counts_per_question = combined_df.drop(columns=["Query"]).apply(lambda row: row.value_counts(), axis=1)

# Display the result
value_counts_per_question.to_csv("responses.csv", index=False)

# %%
combined_df.Query.values[5]
# Out:
# 'How safe would you feel sharing the road with a driverless passenger vehicle?\nPlease respond with EXACTLY one of these phrases: Very safe, Somewhat safe, Not too safe, Not safe at all'

# %%
combined_df.values[12] # most interesting finding: split between unacceptable, acceptable, and not sure
# Out:
# array(['In your opinion, is it acceptable or unacceptable to use facial recognition technology in the following situations? Companies automatically tracking the attendance of their employees\nPlease respond with EXACTLY one of these phrases: Acceptable, Unacceptable, Not sure',
#        'Not sure', 'Not sure', 'Acceptable', 'Not sure', 'Not sure',
#        'Not sure', 'Not sure', 'Not sure', 'Unacceptable', 'Not sure',
#        'Not sure', 'Acceptable', 'Not sure', 'Unacceptable', 'Not sure',
#        'Not sure', 'Not sure', 'Not sure', 'Unacceptable', 'Not sure',
#        'Not sure', 'Acceptable', 'Not sure', 'Unacceptable', 'Not sure',
#        'Not sure', 'Not sure', 'Acceptable', 'Not sure', 'Not sure',
#        'Acceptable', 'Unacceptable', 'Not sure', 'Not sure', 'Not sure',
#        'Unacceptable', 'Unacceptable', 'Not sure', 'Not sure',
#        'Acceptable'], dtype=object)
